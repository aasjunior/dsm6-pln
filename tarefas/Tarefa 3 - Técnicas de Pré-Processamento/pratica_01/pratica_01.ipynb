# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)
pd.set_option('display.colheader_justify', 'left')

# %% [markdown]
# ### 1. COLETA DE DADOS
#
# - Escolher uma empresa real que utilize um e-commerce ao qual seja
# possível coletar informações das avaliações reais realizadas por seus
# clientes.
#
# - Criar a base de dados contendo no mínimo 20 avaliações (positivas,
# negativas e neutras). Esses dados podem estar armazenados em um
# array de strings. Observação: essa etapa já foi realizada na atividade
# `ESTUDO DE CASO: ANÁLISE DE SENTIMENTO DE AVALIAÇÕES DE
# PRODUTOS`.

# %%
# Caminho para o arquivo CSV contendo as avaliações
data_src = 'db/dataset.csv'

# Leitura do arquivo CSV usando Pandas
data = pd.read_csv(data_src)

# Conta o número total de linhas (avaliações)
total_linhas = data.shape[0]

# Exibe todas as avaliações coletadas
data.head(total_linhas)
# Out:
#    Avaliação                                                                                                                                                                                                                     \
# 0   É amplamente elogiado por sua rapidez, ótima câmera e bateria durável, além de não travar durante o uso. O aparelho também é apreciado por suas funções adicionais como NFC e Smart View, e pelo excelente custo-benefício.
# 1                                                              Gostei bastante, a tela tem um ótimo tamanho... achei bem satisfatório para o preço do celular, não tenho com o que reclamar por enquanto, estou bem satisfeito!
# 2                      Celular muito bonito, veio tudo certinho!! só não gostei pq nã embalaram o cell em um saco bolha, e a caixa veio sem nenhuma proteção! mas o telefone não tem nenhum arranhão. Tirando isso, tudo certo.
# 3                                                                                                                                                                  Dei de presente pra minha esposa... Por enquanto tudo certo.
# 4               Por enquanto estou achando muito bom, fotos boas, respostas rápidas da biometria, além disso tem o smart view... fora isso ele é muito bom. Obs o carregador é fraco demorar para carregar o telefone um pouco.
# 5                                                                     Produto muito bom bateria dura bastante só não gostei do tamanho, estou acostumado com celular maior,mas pra quem gosta recomendo podem comprar sem medo.
# 6                                                         O produto tem um design lindo, porém tem pouca durabilidade em relação à bateria... Só não faço a devolução devido a necessidade que eu tenho em relação ao aparelho.
# 7                                                                                                                Eu não tive muito sorte com essa compra, esse celular está com um mês de uso e tá travando... ele não obedece.
# 8                                                                                                         A qualidade das câmeras deixa muito a desejar, mas para um básico, dá pro gasto... precisa adquirir um separadamente.
# 9                                                                                Celular mediano, esperava mais por ser samsung... travando o app usado no momento fazendo com que você desigualdade tela para reiniciar o app.
# 10                                                                                                         Produto infelizmente após poucos meses de uso, apresenta defeitos de travamento e acessos remotos a apps e ligações.
# 11                                                                                                      Produto muito bom bateria dura bastante só não gostei do tamanho...mas pra quem gosta recomendo podem comprar sem medo.
# 12                                                        O produto tem um design lindo, porém tem pouca durabilidade em relação à bateria... Só não faço a devolução devido a necessidade que eu tenho em relação ao aparelho.
# 13                                                                               Ou configuração pois não me adaptei com o a15... mas faz parte, não é ruim mas a configuração tem que sofrer pois já fui em 2 técnico samsung.
# 14                                                                                                                Produto veio errado e me foi negado o reembolso de forma descarada e ilegal com total desprezo ao consumidor.
# 15                                                                                                                            O meu só prestou 3 dias aí não carregou mais e eles não aceitaram a devolução fiquei no prejuízo.
# 16                                                                                                                        Péssima qualidade. Comprei com 1 mes de uso deu problema não tá carregando mais. Péssimo não comprem.
# 17                                                                                                    É um celular bem lento. Bem devagar para abrir apps e executar tarefas simples como copiar e colar texto entre dois apps.
# 18                                                                                                                                 O celular com 1 mês de uso apresentou problemas... Vou ter q mandar pra assistência técnica.
# 19                                     O celular é bom, por onde sai o áudio que parece que não tem uma proteção é como se fosse outro celular que encaixaram em cima dele só tem metade da proteção do audio na parte de cima.
# 20                                                                                                           Nem cinco dia de uso já começou a dar defeito... Mas o celular não 📵 👎. Minha primeira experiência, foi a desejar.
#
#     Classe
# 0   Positivo
# 1   Positivo
# 2     Neutro
# 3     Neutro
# 4   Positivo
# 5   Positivo
# 6     Neutro
# 7   Negativo
# 8     Neutro
# 9   Negativo
# 10  Negativo
# 11  Positivo
# 12    Neutro
# 13    Neutro
# 14  Negativo
# 15  Negativo
# 16  Negativo
# 17  Negativo
# 18  Negativo
# 19    Neutro
# 20  Negativo

# %% [markdown]
# ### 2. LIMPEZA DE TEXTO
#
# - Deve ser realizada a remoção de caracteres especiais, números ou
# símbolos indesejados. É uma etapa opcional, portanto, se a base de
# dados não possuir essas informações, basta pular essa etapa.
#
# #### Explicação:
#
# - **Remover emojis e caracteres especiais**: A função `re.sub()` usa uma expressão regular para remover tudo o que não é letra, número, espaço ou vírgula.
#
# - **Remover aspas duplas**: A função `replace()` remove as aspas duplas do texto, o que pode prevenir erros de formatação em CSV.
#
# - **Aplicação da função**: A função `clean_text()` é aplicada a todas as células contendo texto no DataFrame data, e os dados limpos são salvos em um novo arquivo CSV chamado `dataset_cleaned.csv`.

# %%
import re

def clean_text(text):
    # Remover qualquer coisa que não seja uma letra, número, espaço ou vírgula
    text = re.sub(r'[^\w\s,]', '', text)

    # Remover aspas duplas
    text = text.replace('"', '')

    return text

data = data.apply(lambda x: clean_text(x) if isinstance(x, str) else x)

data.to_csv('db/dataset_cleaned.csv', index=False)

data.head(total_linhas)
# Out:
#    Avaliação                                                                                                                                                                                                                     \
# 0   É amplamente elogiado por sua rapidez, ótima câmera e bateria durável, além de não travar durante o uso. O aparelho também é apreciado por suas funções adicionais como NFC e Smart View, e pelo excelente custo-benefício.
# 1                                                              Gostei bastante, a tela tem um ótimo tamanho... achei bem satisfatório para o preço do celular, não tenho com o que reclamar por enquanto, estou bem satisfeito!
# 2                      Celular muito bonito, veio tudo certinho!! só não gostei pq nã embalaram o cell em um saco bolha, e a caixa veio sem nenhuma proteção! mas o telefone não tem nenhum arranhão. Tirando isso, tudo certo.
# 3                                                                                                                                                                  Dei de presente pra minha esposa... Por enquanto tudo certo.
# 4               Por enquanto estou achando muito bom, fotos boas, respostas rápidas da biometria, além disso tem o smart view... fora isso ele é muito bom. Obs o carregador é fraco demorar para carregar o telefone um pouco.
# 5                                                                     Produto muito bom bateria dura bastante só não gostei do tamanho, estou acostumado com celular maior,mas pra quem gosta recomendo podem comprar sem medo.
# 6                                                         O produto tem um design lindo, porém tem pouca durabilidade em relação à bateria... Só não faço a devolução devido a necessidade que eu tenho em relação ao aparelho.
# 7                                                                                                                Eu não tive muito sorte com essa compra, esse celular está com um mês de uso e tá travando... ele não obedece.
# 8                                                                                                         A qualidade das câmeras deixa muito a desejar, mas para um básico, dá pro gasto... precisa adquirir um separadamente.
# 9                                                                                Celular mediano, esperava mais por ser samsung... travando o app usado no momento fazendo com que você desigualdade tela para reiniciar o app.
# 10                                                                                                         Produto infelizmente após poucos meses de uso, apresenta defeitos de travamento e acessos remotos a apps e ligações.
# 11                                                                                                      Produto muito bom bateria dura bastante só não gostei do tamanho...mas pra quem gosta recomendo podem comprar sem medo.
# 12                                                        O produto tem um design lindo, porém tem pouca durabilidade em relação à bateria... Só não faço a devolução devido a necessidade que eu tenho em relação ao aparelho.
# 13                                                                               Ou configuração pois não me adaptei com o a15... mas faz parte, não é ruim mas a configuração tem que sofrer pois já fui em 2 técnico samsung.
# 14                                                                                                                Produto veio errado e me foi negado o reembolso de forma descarada e ilegal com total desprezo ao consumidor.
# 15                                                                                                                            O meu só prestou 3 dias aí não carregou mais e eles não aceitaram a devolução fiquei no prejuízo.
# 16                                                                                                                        Péssima qualidade. Comprei com 1 mes de uso deu problema não tá carregando mais. Péssimo não comprem.
# 17                                                                                                    É um celular bem lento. Bem devagar para abrir apps e executar tarefas simples como copiar e colar texto entre dois apps.
# 18                                                                                                                                 O celular com 1 mês de uso apresentou problemas... Vou ter q mandar pra assistência técnica.
# 19                                     O celular é bom, por onde sai o áudio que parece que não tem uma proteção é como se fosse outro celular que encaixaram em cima dele só tem metade da proteção do audio na parte de cima.
# 20                                                                                                           Nem cinco dia de uso já começou a dar defeito... Mas o celular não 📵 👎. Minha primeira experiência, foi a desejar.
#
#     Classe
# 0   Positivo
# 1   Positivo
# 2     Neutro
# 3     Neutro
# 4   Positivo
# 5   Positivo
# 6     Neutro
# 7   Negativo
# 8     Neutro
# 9   Negativo
# 10  Negativo
# 11  Positivo
# 12    Neutro
# 13    Neutro
# 14  Negativo
# 15  Negativo
# 16  Negativo
# 17  Negativo
# 18  Negativo
# 19    Neutro
# 20  Negativo

# %% [markdown]
# ### 3. TOKENIZAÇÃO
#
# - Dividir cada texto (avaliação) em palavras (tokens) ou frases (sentenças).
# Isso é essencial para as análises subsequentes.
#
#
# O código usa a biblioteca `NLTK` para realizar a tokenização das avaliações de produtos. Ele extrai as avaliações de um **DataFrame**, converte-as para uma lista de strings e depois divide cada string em tokens (palavras). Esse processo é fundamental para a análise de sentimentos, pois permite que o modelo de **PLN** identifique padrões linguísticos nas avaliações.

# %%
import nltk

# Lista com as avaliações
texts = data.iloc[:, 0].tolist()
print(f'Avaliações: \n{texts}\n\n')

tokenized = [nltk.word_tokenize(text) for text in texts]

print(f'Avaliações tokenizadas: \n{tokenized}')
# Out:
# Avaliações:
# ['É amplamente elogiado por sua rapidez, ótima câmera e bateria durável, além de não travar durante o uso. O aparelho também é apreciado por suas funções adicionais como NFC e Smart View, e pelo excelente custo-benefício.', 'Gostei bastante, a tela tem um ótimo tamanho... achei bem satisfatório para o preço do celular, não tenho com o que reclamar por enquanto, estou bem satisfeito!', 'Celular muito bonito, veio tudo certinho!! só não gostei pq nã embalaram o cell em um saco bolha, e a caixa veio sem nenhuma proteção! mas o telefone não tem nenhum arranhão. Tirando isso, tudo certo.', 'Dei de presente pra minha esposa... Por enquanto tudo certo.', 'Por enquanto estou achando muito bom, fotos boas, respostas rápidas da biometria, além disso tem o smart view... fora isso ele é muito bom. Obs o carregador é fraco demorar para carregar o telefone um pouco.', 'Produto muito bom bateria dura bastante só não gostei do tamanho, estou acostumado com celular maior,mas pra quem gosta recomendo podem comprar sem medo.', 'O produto tem um design lindo, porém tem pouca durabilidade em relação à bateria... Só não faço a devolução devido a necessidade que eu tenho em relação ao aparelho.', 'Eu não tive muito sorte com essa compra, esse celular está com um mês de uso e tá travando... ele não obedece.', 'A qualidade das câmeras deixa muito a desejar, mas para um básico, dá pro gasto... precisa adquirir um separadamente.', 'Celular mediano, esperava mais por ser samsung... travando o app usado no momento fazendo com que você desigualdade tela para reiniciar o app.', 'Produto infelizmente após poucos meses de uso, apresenta defeitos de travamento e acessos remotos a apps e ligações.', 'Produto muito bom bateria dura bastante só não gostei do tamanho...mas pra quem gosta recomendo podem comprar sem medo.', 'O produto tem um design lindo, porém tem pouca durabilidade em relação à bateria... Só não faço a devolução devido a necessidade que eu tenho em relação ao aparelho.', 'Ou configuração pois não me adaptei com o a15... mas faz parte, não é ruim mas a configuração tem que sofrer pois já fui em 2 técnico samsung.', 'Produto veio errado e me foi negado o reembolso de forma descarada e ilegal com total desprezo ao consumidor.', 'O meu só prestou 3 dias aí não carregou mais e eles não aceitaram a devolução fiquei no prejuízo.', 'Péssima qualidade. Comprei com 1 mes de uso deu problema não tá carregando mais. Péssimo não comprem.', 'É um celular bem lento. Bem devagar para abrir apps e executar tarefas simples como copiar e colar texto entre dois apps.', 'O celular com 1 mês de uso apresentou problemas... Vou ter q mandar pra assistência técnica.', 'O celular é bom, por onde sai o áudio que parece que não tem uma proteção é como se fosse outro celular que encaixaram em cima dele só tem metade da proteção do audio na parte de cima.', 'Nem cinco dia de uso já começou a dar defeito... Mas o celular não 📵 👎. Minha primeira experiência, foi a desejar.']
#
#
# Avaliações tokenizadas:
# [['É', 'amplamente', 'elogiado', 'por', 'sua', 'rapidez', ',', 'ótima', 'câmera', 'e', 'bateria', 'durável', ',', 'além', 'de', 'não', 'travar', 'durante', 'o', 'uso', '.', 'O', 'aparelho', 'também', 'é', 'apreciado', 'por', 'suas', 'funções', 'adicionais', 'como', 'NFC', 'e', 'Smart', 'View', ',', 'e', 'pelo', 'excelente', 'custo-benefício', '.'], ['Gostei', 'bastante', ',', 'a', 'tela', 'tem', 'um', 'ótimo', 'tamanho', '...', 'achei', 'bem', 'satisfatório', 'para', 'o', 'preço', 'do', 'celular', ',', 'não', 'tenho', 'com', 'o', 'que', 'reclamar', 'por', 'enquanto', ',', 'estou', 'bem', 'satisfeito', '!'], ['Celular', 'muito', 'bonito', ',', 'veio', 'tudo', 'certinho', '!', '!', 'só', 'não', 'gostei', 'pq', 'nã', 'embalaram', 'o', 'cell', 'em', 'um', 'saco', 'bolha', ',', 'e', 'a', 'caixa', 'veio', 'sem', 'nenhuma', 'proteção', '!', 'mas', 'o', 'telefone', 'não', 'tem', 'nenhum', 'arranhão', '.', 'Tirando', 'isso', ',', 'tudo', 'certo', '.'], ['Dei', 'de', 'presente', 'pra', 'minha', 'esposa', '...', 'Por', 'enquanto', 'tudo', 'certo', '.'], ['Por', 'enquanto', 'estou', 'achando', 'muito', 'bom', ',', 'fotos', 'boas', ',', 'respostas', 'rápidas', 'da', 'biometria', ',', 'além', 'disso', 'tem', 'o', 'smart', 'view', '...', 'fora', 'isso', 'ele', 'é', 'muito', 'bom', '.', 'Obs', 'o', 'carregador', 'é', 'fraco', 'demorar', 'para', 'carregar', 'o', 'telefone', 'um', 'pouco', '.'], ['Produto', 'muito', 'bom', 'bateria', 'dura', 'bastante', 'só', 'não', 'gostei', 'do', 'tamanho', ',', 'estou', 'acostumado', 'com', 'celular', 'maior', ',', 'mas', 'pra', 'quem', 'gosta', 'recomendo', 'podem', 'comprar', 'sem', 'medo', '.'], ['O', 'produto', 'tem', 'um', 'design', 'lindo', ',', 'porém', 'tem', 'pouca', 'durabilidade', 'em', 'relação', 'à', 'bateria', '...', 'Só', 'não', 'faço', 'a', 'devolução', 'devido', 'a', 'necessidade', 'que', 'eu', 'tenho', 'em', 'relação', 'ao', 'aparelho', '.'], ['Eu', 'não', 'tive', 'muito', 'sorte', 'com', 'essa', 'compra', ',', 'esse', 'celular', 'está', 'com', 'um', 'mês', 'de', 'uso', 'e', 'tá', 'travando', '...', 'ele', 'não', 'obedece', '.'], ['A', 'qualidade', 'das', 'câmeras', 'deixa', 'muito', 'a', 'desejar', ',', 'mas', 'para', 'um', 'básico', ',', 'dá', 'pro', 'gasto', '...', 'precisa', 'adquirir', 'um', 'separadamente', '.'], ['Celular', 'mediano', ',', 'esperava', 'mais', 'por', 'ser', 'samsung', '...', 'travando', 'o', 'app', 'usado', 'no', 'momento', 'fazendo', 'com', 'que', 'você', 'desigualdade', 'tela', 'para', 'reiniciar', 'o', 'app', '.'], ['Produto', 'infelizmente', 'após', 'poucos', 'meses', 'de', 'uso', ',', 'apresenta', 'defeitos', 'de', 'travamento', 'e', 'acessos', 'remotos', 'a', 'apps', 'e', 'ligações', '.'], ['Produto', 'muito', 'bom', 'bateria', 'dura', 'bastante', 'só', 'não', 'gostei', 'do', 'tamanho', '...', 'mas', 'pra', 'quem', 'gosta', 'recomendo', 'podem', 'comprar', 'sem', 'medo', '.'], ['O', 'produto', 'tem', 'um', 'design', 'lindo', ',', 'porém', 'tem', 'pouca', 'durabilidade', 'em', 'relação', 'à', 'bateria', '...', 'Só', 'não', 'faço', 'a', 'devolução', 'devido', 'a', 'necessidade', 'que', 'eu', 'tenho', 'em', 'relação', 'ao', 'aparelho', '.'], ['Ou', 'configuração', 'pois', 'não', 'me', 'adaptei', 'com', 'o', 'a15', '...', 'mas', 'faz', 'parte', ',', 'não', 'é', 'ruim', 'mas', 'a', 'configuração', 'tem', 'que', 'sofrer', 'pois', 'já', 'fui', 'em', '2', 'técnico', 'samsung', '.'], ['Produto', 'veio', 'errado', 'e', 'me', 'foi', 'negado', 'o', 'reembolso', 'de', 'forma', 'descarada', 'e', 'ilegal', 'com', 'total', 'desprezo', 'ao', 'consumidor', '.'], ['O', 'meu', 'só', 'prestou', '3', 'dias', 'aí', 'não', 'carregou', 'mais', 'e', 'eles', 'não', 'aceitaram', 'a', 'devolução', 'fiquei', 'no', 'prejuízo', '.'], ['Péssima', 'qualidade', '.', 'Comprei', 'com', '1', 'mes', 'de', 'uso', 'deu', 'problema', 'não', 'tá', 'carregando', 'mais', '.', 'Péssimo', 'não', 'comprem', '.'], ['É', 'um', 'celular', 'bem', 'lento', '.', 'Bem', 'devagar', 'para', 'abrir', 'apps', 'e', 'exec ...

# %% [markdown]
# ### 4. NORMALIZAÇÃO
# - `LOWERCASING`: Converter todo o texto para minúsculas para evitar
# duplicação de palavras por causa de capitalização.
#
# - `RADICALIZAÇÃO`: Remover os sufixos de palavras para chegar a raiz,
# embora isso possa ser menos preciso que a lematização dependendo do
# contexto.

# %%
# Lowercasing
words = [[word.lower() for word in review] for review in tokenized]
print(f'Palavras convertidas para letras minusculas: \n{words}\n\n')

# Radicalização
snowballStemmer = nltk.SnowballStemmer('portuguese')

radicalized = [[snowballStemmer.stem(word) for word in review] for review in words]
print(f'Remoção dos sufixos para chegar a raiz (Radicalização): \n{radicalized}\n\n')
# Out:
# Palavras convertidas para letras minusculas:
# [['é', 'amplamente', 'elogiado', 'por', 'sua', 'rapidez', ',', 'ótima', 'câmera', 'e', 'bateria', 'durável', ',', 'além', 'de', 'não', 'travar', 'durante', 'o', 'uso', '.', 'o', 'aparelho', 'também', 'é', 'apreciado', 'por', 'suas', 'funções', 'adicionais', 'como', 'nfc', 'e', 'smart', 'view', ',', 'e', 'pelo', 'excelente', 'custo-benefício', '.'], ['gostei', 'bastante', ',', 'a', 'tela', 'tem', 'um', 'ótimo', 'tamanho', '...', 'achei', 'bem', 'satisfatório', 'para', 'o', 'preço', 'do', 'celular', ',', 'não', 'tenho', 'com', 'o', 'que', 'reclamar', 'por', 'enquanto', ',', 'estou', 'bem', 'satisfeito', '!'], ['celular', 'muito', 'bonito', ',', 'veio', 'tudo', 'certinho', '!', '!', 'só', 'não', 'gostei', 'pq', 'nã', 'embalaram', 'o', 'cell', 'em', 'um', 'saco', 'bolha', ',', 'e', 'a', 'caixa', 'veio', 'sem', 'nenhuma', 'proteção', '!', 'mas', 'o', 'telefone', 'não', 'tem', 'nenhum', 'arranhão', '.', 'tirando', 'isso', ',', 'tudo', 'certo', '.'], ['dei', 'de', 'presente', 'pra', 'minha', 'esposa', '...', 'por', 'enquanto', 'tudo', 'certo', '.'], ['por', 'enquanto', 'estou', 'achando', 'muito', 'bom', ',', 'fotos', 'boas', ',', 'respostas', 'rápidas', 'da', 'biometria', ',', 'além', 'disso', 'tem', 'o', 'smart', 'view', '...', 'fora', 'isso', 'ele', 'é', 'muito', 'bom', '.', 'obs', 'o', 'carregador', 'é', 'fraco', 'demorar', 'para', 'carregar', 'o', 'telefone', 'um', 'pouco', '.'], ['produto', 'muito', 'bom', 'bateria', 'dura', 'bastante', 'só', 'não', 'gostei', 'do', 'tamanho', ',', 'estou', 'acostumado', 'com', 'celular', 'maior', ',', 'mas', 'pra', 'quem', 'gosta', 'recomendo', 'podem', 'comprar', 'sem', 'medo', '.'], ['o', 'produto', 'tem', 'um', 'design', 'lindo', ',', 'porém', 'tem', 'pouca', 'durabilidade', 'em', 'relação', 'à', 'bateria', '...', 'só', 'não', 'faço', 'a', 'devolução', 'devido', 'a', 'necessidade', 'que', 'eu', 'tenho', 'em', 'relação', 'ao', 'aparelho', '.'], ['eu', 'não', 'tive', 'muito', 'sorte', 'com', 'essa', 'compra', ',', 'esse', 'celular', 'está', 'com', 'um', 'mês', 'de', 'uso', 'e', 'tá', 'travando', '...', 'ele', 'não', 'obedece', '.'], ['a', 'qualidade', 'das', 'câmeras', 'deixa', 'muito', 'a', 'desejar', ',', 'mas', 'para', 'um', 'básico', ',', 'dá', 'pro', 'gasto', '...', 'precisa', 'adquirir', 'um', 'separadamente', '.'], ['celular', 'mediano', ',', 'esperava', 'mais', 'por', 'ser', 'samsung', '...', 'travando', 'o', 'app', 'usado', 'no', 'momento', 'fazendo', 'com', 'que', 'você', 'desigualdade', 'tela', 'para', 'reiniciar', 'o', 'app', '.'], ['produto', 'infelizmente', 'após', 'poucos', 'meses', 'de', 'uso', ',', 'apresenta', 'defeitos', 'de', 'travamento', 'e', 'acessos', 'remotos', 'a', 'apps', 'e', 'ligações', '.'], ['produto', 'muito', 'bom', 'bateria', 'dura', 'bastante', 'só', 'não', 'gostei', 'do', 'tamanho', '...', 'mas', 'pra', 'quem', 'gosta', 'recomendo', 'podem', 'comprar', 'sem', 'medo', '.'], ['o', 'produto', 'tem', 'um', 'design', 'lindo', ',', 'porém', 'tem', 'pouca', 'durabilidade', 'em', 'relação', 'à', 'bateria', '...', 'só', 'não', 'faço', 'a', 'devolução', 'devido', 'a', 'necessidade', 'que', 'eu', 'tenho', 'em', 'relação', 'ao', 'aparelho', '.'], ['ou', 'configuração', 'pois', 'não', 'me', 'adaptei', 'com', 'o', 'a15', '...', 'mas', 'faz', 'parte', ',', 'não', 'é', 'ruim', 'mas', 'a', 'configuração', 'tem', 'que', 'sofrer', 'pois', 'já', 'fui', 'em', '2', 'técnico', 'samsung', '.'], ['produto', 'veio', 'errado', 'e', 'me', 'foi', 'negado', 'o', 'reembolso', 'de', 'forma', 'descarada', 'e', 'ilegal', 'com', 'total', 'desprezo', 'ao', 'consumidor', '.'], ['o', 'meu', 'só', 'prestou', '3', 'dias', 'aí', 'não', 'carregou', 'mais', 'e', 'eles', 'não', 'aceitaram', 'a', 'devolução', 'fiquei', 'no', 'prejuízo', '.'], ['péssima', 'qualidade', '.', 'comprei', 'com', '1', 'mes', 'de', 'uso', 'deu', 'problema', 'não', 'tá', 'carregando', 'mais', '.', 'péssimo', 'não', 'comprem', '.'], ['é', 'um', 'celular', 'bem', 'lento', '.', 'bem', 'devagar', 'para', 'abrir', 'apps', 'e', 'exec ...
#
#
# Remoção dos sufixos para chegar a raiz (Radicalização):
# [['é', 'ampl', 'elogi', 'por', 'sua', 'rapidez', ',', 'ótim', 'câm', 'e', 'bat', 'durável', ',', 'além', 'de', 'nã', 'trav', 'durant', 'o', 'uso', '.', 'o', 'aparelh', 'também', 'é', 'aprec', 'por', 'suas', 'funçõ', 'adicion', 'com', 'nfc', 'e', 'smart', 'view', ',', 'e', 'pel', 'excelent', 'custo-benefíci', '.'], ['gost', 'bastant', ',', 'a', 'tel', 'tem', 'um', 'ótim', 'tamanh', '...', 'ache', 'bem', 'satisfatóri', 'par', 'o', 'prec', 'do', 'celul', ',', 'nã', 'tenh', 'com', 'o', 'que', 'reclam', 'por', 'enquant', ',', 'estou', 'bem', 'satisfeit', '!'], ['celul', 'muit', 'bonit', ',', 'vei', 'tud', 'certinh', '!', '!', 'só', 'nã', 'gost', 'pq', 'nã', 'embal', 'o', 'cell', 'em', 'um', 'sac', 'bolh', ',', 'e', 'a', 'caix', 'vei', 'sem', 'nenhum', 'proteçã', '!', 'mas', 'o', 'telefon', 'nã', 'tem', 'nenhum', 'arranhã', '.', 'tir', 'isso', ',', 'tud', 'cert', '.'], ['dei', 'de', 'present', 'pra', 'minh', 'espos', '...', 'por', 'enquant', 'tud', 'cert', '.'], ['por', 'enquant', 'estou', 'achand', 'muit', 'bom', ',', 'fot', 'boas', ',', 'respost', 'ráp', 'da', 'biometr', ',', 'além', 'diss', 'tem', 'o', 'smart', 'view', '...', 'for', 'isso', 'ele', 'é', 'muit', 'bom', '.', 'obs', 'o', 'carreg', 'é', 'frac', 'demor', 'par', 'carreg', 'o', 'telefon', 'um', 'pouc', '.'], ['produt', 'muit', 'bom', 'bat', 'dur', 'bastant', 'só', 'nã', 'gost', 'do', 'tamanh', ',', 'estou', 'acostum', 'com', 'celul', 'maior', ',', 'mas', 'pra', 'quem', 'gost', 'recom', 'pod', 'compr', 'sem', 'med', '.'], ['o', 'produt', 'tem', 'um', 'design', 'lind', ',', 'porém', 'tem', 'pouc', 'durabil', 'em', 'relaçã', 'à', 'bat', '...', 'só', 'nã', 'fac', 'a', 'devolu', 'dev', 'a', 'necess', 'que', 'eu', 'tenh', 'em', 'relaçã', 'ao', 'aparelh', '.'], ['eu', 'nã', 'tiv', 'muit', 'sort', 'com', 'essa', 'compr', ',', 'esse', 'celul', 'está', 'com', 'um', 'mês', 'de', 'uso', 'e', 'tá', 'trav', '...', 'ele', 'nã', 'obedec', '.'], ['a', 'qualidad', 'das', 'câm', 'deix', 'muit', 'a', 'desej', ',', 'mas', 'par', 'um', 'básic', ',', 'dá', 'pro', 'gast', '...', 'precis', 'adquir', 'um', 'separ', '.'], ['celul', 'median', ',', 'esper', 'mais', 'por', 'ser', 'samsung', '...', 'trav', 'o', 'app', 'usad', 'no', 'moment', 'faz', 'com', 'que', 'voc', 'desigualdad', 'tel', 'par', 'reinic', 'o', 'app', '.'], ['produt', 'infeliz', 'após', 'pouc', 'mes', 'de', 'uso', ',', 'apresent', 'defeit', 'de', 'travament', 'e', 'acess', 'remot', 'a', 'apps', 'e', 'ligaçõ', '.'], ['produt', 'muit', 'bom', 'bat', 'dur', 'bastant', 'só', 'nã', 'gost', 'do', 'tamanh', '...', 'mas', 'pra', 'quem', 'gost', 'recom', 'pod', 'compr', 'sem', 'med', '.'], ['o', 'produt', 'tem', 'um', 'design', 'lind', ',', 'porém', 'tem', 'pouc', 'durabil', 'em', 'relaçã', 'à', 'bat', '...', 'só', 'nã', 'fac', 'a', 'devolu', 'dev', 'a', 'necess', 'que', 'eu', 'tenh', 'em', 'relaçã', 'ao', 'aparelh', '.'], ['ou', 'configur', 'pois', 'nã', 'me', 'adapt', 'com', 'o', 'a15', '...', 'mas', 'faz', 'part', ',', 'nã', 'é', 'ruim', 'mas', 'a', 'configur', 'tem', 'que', 'sofr', 'pois', 'já', 'fui', 'em', '2', 'técnic', 'samsung', '.'], ['produt', 'vei', 'errad', 'e', 'me', 'foi', 'neg', 'o', 'reembols', 'de', 'form', 'descar', 'e', 'ilegal', 'com', 'total', 'desprez', 'ao', 'consumidor', '.'], ['o', 'meu', 'só', 'prest', '3', 'dias', 'aí', 'nã', 'carreg', 'mais', 'e', 'eles', 'nã', 'aceit', 'a', 'devolu', 'fiqu', 'no', 'prejuíz', '.'], ['péssim', 'qualidad', '.', 'compr', 'com', '1', 'mes', 'de', 'uso', 'deu', 'problem', 'nã', 'tá', 'carreg', 'mais', '.', 'péssim', 'nã', 'compr', '.'], ['é', 'um', 'celul', 'bem', 'lent', '.', 'bem', 'devag', 'par', 'abrir', 'apps', 'e', 'execut', 'taref', 'simpl', 'com', 'copi', 'e', 'col', 'text', 'entre', 'dois', 'apps', '.'], ['o', 'celul', 'com', '1', 'mês', 'de', 'uso', 'apresent', 'problem', '...', 'vou', 'ter', 'q', 'mand', 'pra', 'assistent', 'técnic', '.'], ['o', 'celul', 'é', 'bom', ',', 'por', 'onde', 'sai', 'o', 'áudi', 'que', 'parec', 'que', 'nã', 'tem', 'uma', 'proteçã', 'é', 'com', 'se' ...

# %% [markdown]
# ### 5. REMOÇÃO DE STOPWORDS
#
# - `Stop words` são palavras comuns (artigos, pronomes, advérbios,
# preposições, entre outras) que muitas vezes são removidas, pois podem
# não contribuir para a análise que está sendo realizada.

# %%
stopwords = nltk.corpus.stopwords.words('portuguese')

responses = [[word for word in review if word not in stopwords] for review in words]
print(f'Avaliações sem stopwords: \n{responses}\n\n')

# Radicalização sem as stopwords
responses_radicalized = [[snowballStemmer.stem(word) for word in review] for review in responses]
print(f'Avaliações sem stopwords e radicalizada: \n{responses_radicalized}\n\n')
# Out:
# Avaliações sem stopwords:
# [['amplamente', 'elogiado', 'rapidez', ',', 'ótima', 'câmera', 'bateria', 'durável', ',', 'além', 'travar', 'durante', 'uso', '.', 'aparelho', 'apreciado', 'funções', 'adicionais', 'nfc', 'smart', 'view', ',', 'excelente', 'custo-benefício', '.'], ['gostei', 'bastante', ',', 'tela', 'ótimo', 'tamanho', '...', 'achei', 'bem', 'satisfatório', 'preço', 'celular', ',', 'reclamar', 'enquanto', ',', 'bem', 'satisfeito', '!'], ['celular', 'bonito', ',', 'veio', 'tudo', 'certinho', '!', '!', 'gostei', 'pq', 'nã', 'embalaram', 'cell', 'saco', 'bolha', ',', 'caixa', 'veio', 'nenhuma', 'proteção', '!', 'telefone', 'nenhum', 'arranhão', '.', 'tirando', ',', 'tudo', 'certo', '.'], ['dei', 'presente', 'pra', 'esposa', '...', 'enquanto', 'tudo', 'certo', '.'], ['enquanto', 'achando', 'bom', ',', 'fotos', 'boas', ',', 'respostas', 'rápidas', 'biometria', ',', 'além', 'disso', 'smart', 'view', '...', 'bom', '.', 'obs', 'carregador', 'fraco', 'demorar', 'carregar', 'telefone', 'pouco', '.'], ['produto', 'bom', 'bateria', 'dura', 'bastante', 'gostei', 'tamanho', ',', 'acostumado', 'celular', 'maior', ',', 'pra', 'gosta', 'recomendo', 'podem', 'comprar', 'medo', '.'], ['produto', 'design', 'lindo', ',', 'porém', 'pouca', 'durabilidade', 'relação', 'bateria', '...', 'faço', 'devolução', 'devido', 'necessidade', 'relação', 'aparelho', '.'], ['sorte', 'compra', ',', 'celular', 'mês', 'uso', 'tá', 'travando', '...', 'obedece', '.'], ['qualidade', 'câmeras', 'deixa', 'desejar', ',', 'básico', ',', 'dá', 'pro', 'gasto', '...', 'precisa', 'adquirir', 'separadamente', '.'], ['celular', 'mediano', ',', 'esperava', 'samsung', '...', 'travando', 'app', 'usado', 'momento', 'fazendo', 'desigualdade', 'tela', 'reiniciar', 'app', '.'], ['produto', 'infelizmente', 'após', 'poucos', 'meses', 'uso', ',', 'apresenta', 'defeitos', 'travamento', 'acessos', 'remotos', 'apps', 'ligações', '.'], ['produto', 'bom', 'bateria', 'dura', 'bastante', 'gostei', 'tamanho', '...', 'pra', 'gosta', 'recomendo', 'podem', 'comprar', 'medo', '.'], ['produto', 'design', 'lindo', ',', 'porém', 'pouca', 'durabilidade', 'relação', 'bateria', '...', 'faço', 'devolução', 'devido', 'necessidade', 'relação', 'aparelho', '.'], ['configuração', 'pois', 'adaptei', 'a15', '...', 'faz', 'parte', ',', 'ruim', 'configuração', 'sofrer', 'pois', '2', 'técnico', 'samsung', '.'], ['produto', 'veio', 'errado', 'negado', 'reembolso', 'forma', 'descarada', 'ilegal', 'total', 'desprezo', 'consumidor', '.'], ['prestou', '3', 'dias', 'aí', 'carregou', 'aceitaram', 'devolução', 'fiquei', 'prejuízo', '.'], ['péssima', 'qualidade', '.', 'comprei', '1', 'mes', 'uso', 'deu', 'problema', 'tá', 'carregando', '.', 'péssimo', 'comprem', '.'], ['celular', 'bem', 'lento', '.', 'bem', 'devagar', 'abrir', 'apps', 'executar', 'tarefas', 'simples', 'copiar', 'colar', 'texto', 'dois', 'apps', '.'], ['celular', '1', 'mês', 'uso', 'apresentou', 'problemas', '...', 'vou', 'ter', 'q', 'mandar', 'pra', 'assistência', 'técnica', '.'], ['celular', 'bom', ',', 'onde', 'sai', 'áudio', 'parece', 'proteção', 'outro', 'celular', 'encaixaram', 'cima', 'metade', 'proteção', 'audio', 'parte', 'cima', '.'], ['cinco', 'dia', 'uso', 'começou', 'dar', 'defeito', '...', 'celular', '📵', '👎', '.', 'primeira', 'experiência', ',', 'desejar', '.']]
#
#
# Avaliações sem stopwords e radicalizada:
# [['ampl', 'elogi', 'rapidez', ',', 'ótim', 'câm', 'bat', 'durável', ',', 'além', 'trav', 'durant', 'uso', '.', 'aparelh', 'aprec', 'funçõ', 'adicion', 'nfc', 'smart', 'view', ',', 'excelent', 'custo-benefíci', '.'], ['gost', 'bastant', ',', 'tel', 'ótim', 'tamanh', '...', 'ache', 'bem', 'satisfatóri', 'prec', 'celul', ',', 'reclam', 'enquant', ',', 'bem', 'satisfeit', '!'], ['celul', 'bonit', ',', 'vei', 'tud', 'certinh', '!', '!', 'gost', 'pq', 'nã', 'embal', 'cell', 'sac', 'bolh', ',', 'caix', 'vei', 'nenhum', 'proteçã', '!', 'telefon', 'nenhum', 'arranhã', '.', 'tir', ',', 'tud', 'cert', '.'], ['dei', 'present', 'pra', 'espos', '...', 'enquant', 'tud', 'cert', '.'], ['enquant', 'achand', 'bom', ',', 'fot', 'boas', ',', 'respost', 'ráp', 'biometr', ',', 'além', 'diss', 'smart', 'view', '...', 'bom', '.', 'obs', 'carreg', 'frac', 'demor', 'carreg', 'telefon', 'pouc', '.'], ['produt', 'bom', 'bat', 'dur', 'bastant', 'gost', 'tamanh', ',', 'acostum', 'celul', 'maior', ',', 'pra', 'gost', 'recom', 'pod', 'compr', 'med', '.'], ['produt', 'design', 'lind', ',', 'porém', 'pouc', 'durabil', 'relaçã', 'bat', '...', 'fac', 'devolu', 'dev', 'necess', 'relaçã', 'aparelh', '.'], ['sort', 'compr', ',', 'celul', 'mês', 'uso', 'tá', 'trav', '...', 'obedec', '.'], ['qualidad', 'câm', 'deix', 'desej', ',', 'básic', ',', 'dá', 'pro', 'gast', '...', 'precis', 'adquir', 'separ', '.'], ['celul', 'median', ',', 'esper', 'samsung', '...', 'trav', 'app', 'usad', 'moment', 'faz', 'desigualdad', 'tel', 'reinic', 'app', '.'], ['produt', 'infeliz', 'após', 'pouc', 'mes', 'uso', ',', 'apresent', 'defeit', 'travament', 'acess', 'remot', 'apps', 'ligaçõ', '.'], ['produt', 'bom', 'bat', 'dur', 'bastant', 'gost', 'tamanh', '...', 'pra', 'gost', 'recom', 'pod', 'compr', 'med', '.'], ['produt', 'design', 'lind', ',', 'porém', 'pouc', 'durabil', 'relaçã', 'bat', '...', 'fac', 'devolu', 'dev', 'necess', 'relaçã', 'aparelh', '.'], ['configur', 'pois', 'adapt', 'a15', '...', 'faz', 'part', ',', 'ruim', 'configur', 'sofr', 'pois', '2', 'técnic', 'samsung', '.'], ['produt', 'vei', 'errad', 'neg', 'reembols', 'form', 'descar', 'ilegal', 'total', 'desprez', 'consumidor', '.'], ['prest', '3', 'dias', 'aí', 'carreg', 'aceit', 'devolu', 'fiqu', 'prejuíz', '.'], ['péssim', 'qualidad', '.', 'compr', '1', 'mes', 'uso', 'deu', 'problem', 'tá', 'carreg', '.', 'péssim', 'compr', '.'], ['celul', 'bem', 'lent', '.', 'bem', 'devag', 'abrir', 'apps', 'execut', 'taref', 'simpl', 'copi', 'col', 'text', 'dois', 'apps', '.'], ['celul', '1', 'mês', 'uso', 'apresent', 'problem', '...', 'vou', 'ter', 'q', 'mand', 'pra', 'assistent', 'técnic', '.'], ['celul', 'bom', ',', 'onde', 'sai', 'áudi', 'parec', 'proteçã', 'outr', 'celul', 'encaix', 'cim', 'metad', 'proteçã', 'audi', 'part', 'cim', '.'], ['cinc', 'dia', 'uso', 'comec', 'dar', 'defeit', '...', 'celul', '📵', '👎', '.', 'primeir', 'experient', ',', 'desej', '.']]

# %% [markdown]
# ### 6. EXTRAÇÃO DE CARACTERÍSTICAS
#
# - Extraia as seguintes características da base de dados: quantidade de
# registros, quantidade de tokens e quantidade de types.
#
# - Realize a operação de `POS Tagging` (Part-of-Speech Tagging). O `POS
# Tagging` é o processo de marcar as palavras em um texto com suas
# respectivas categorias gramaticais, como substantivos, verbos, adjetivos,
# entre outros.

# %%
# Contagem de registros (avaliações)
print(f'Quantidade de registros: {total_linhas}')

# Contagem de tokens
num_tokens = sum(len(token_list) for token_list in tokenized)
print(f'Quantidade de tokens: {num_tokens}')

# Contagem de types (palavras únicas)
types = set(word.lower() for token_list in tokenized for word in token_list)
num_types = len(types)
print(f'Quantidade de types (tipos únicos de tokens): {num_types}')
print(f'Types: {types}\n')

# POS Tagging
pos_tagged = [nltk.pos_tag(review) for review in responses]
print(f'POS Tagging: \n{pos_tagged}\n\n')

# Análise semântica (Chunking)
chunks = [nltk.ne_chunk(tagged) for tagged in pos_tagged]
print(f'Chunks: \n{chunks}\n\n')
# Out:
# Quantidade de registros: 21
# Quantidade de tokens: 578
# Quantidade de types (tipos únicos de tokens): 258
# Types: {'presente', 'metade', 'mediano', 'ligações', '...', 'começou', 'faz', 'arranhão', 'áudio', 'cima', 'abrir', 'devido', 'app', 'fui', 'embalaram', 'é', 'eles', 'das', 'fosse', 'tudo', 'saco', '.', 'câmera', 'achando', 'carregador', 'mes', 'separadamente', 'além', 'bom', 'certinho', 'ilegal', 'ruim', 'não', '2', 'sua', 'tarefas', 'carregar', 'prejuízo', 'tá', 'achei', 'péssima', 'na', 'dele', 'devolução', 'smart', 'também', 'travamento', 'celular', 'telefone', 'gosta', 'poucos', 'bolha', 'podem', 'dei', 'só', 'pouca', 'total', 'problema', 'entre', 'encaixaram', 'q', 'rapidez', 'carregou', 'ter', 'comprei', 'consumidor', 'estou', 'eu', 'caixa', 'fiquei', 'como', 'que', 'ser', 'ótimo', 'proteção', 'usado', 'forma', 'com', 'recomendo', 'faço', 'do', 'carregando', 'satisfeito', 'sem', 'parece', 'bastante', 'experiência', '👎', 'você', 'dá', 'onde', 'o', 'pra', 'sai', 'nã', 'texto', 'acostumado', 'dar', '📵', 'mas', 'qualidade', 'foi', 'se', 'aí', 'fotos', 'configuração', 'nenhuma', 'está', 'câmeras', 'mais', 'prestou', 'tem', 'adquirir', 'uso', 'técnico', 'certo', 'obedece', 'pelo', 'mês', 'técnica', 'ótima', 'durante', 'dura', 'outro', 'obs', 'comprem', 'uma', 'primeira', 'desigualdade', 'suas', 'comprar', 'produto', 'deixa', 'reiniciar', 'enquanto', 'bonito', 'ou', 'nem', 'adicionais', '3', 'gasto', 'travando', 'à', 'biometria', 'necessidade', 'acessos', 'reclamar', 'em', 'cinco', 'bateria', 'quem', 'esposa', 'elogiado', 'ele', 'tirando', 'defeitos', 'tela', 'e', 'tenho', 'tamanho', 'respostas', 'medo', 'muito', 'básico', 'descarada', 'desprezo', 'problemas', 'vou', 'fora', 'por', 'a', 'fraco', 'dois', 'dias', 'precisa', 'meu', 'esperava', 'durável', 'da', 'meses', 'me', 'colar', 'apreciado', ',', 'parte', 'assistência', 'lento', 'demorar', 'essa', '1', 'devagar', 'desejar', 'audio', 'adaptei', 'satisfatório', 'lindo', 'pouco', 'apresenta', 'para', 'mandar', 'bem', 'porém', 'no', 'aceitaram', 'custo-benefício', 'travar', 'copiar', 'negado', 'amplamente', 'funções', 'executar', 'errado', 'excelente', 'durabilidade', 'preço', 'simples', 'pq', 'nenhum', 'reembolso', 'isso', 'defeito', 'momento', 'apps', 'veio', 'sorte', 'tive', 'design', 'disso', 'dia', 'pro', 'ao', 'pois', 'compra', 'a15', 'de', 'infelizmente', 'remotos', 'apresentou', 'péssimo', 'boas', 'rápidas', 'view', 'relação', 'gostei', 'cell', 'maior', 'aparelho', 'samsung', 'após', 'já', 'fazendo', 'deu', 'esse', 'nfc', '!', 'sofrer', 'um', 'minha'}
#
# POS Tagging:
# [[('amplamente', 'NN'), ('elogiado', 'NN'), ('rapidez', 'NN'), (',', ','), ('ótima', 'NNP'), ('câmera', 'NN'), ('bateria', 'NN'), ('durável', 'NN'), (',', ','), ('além', 'JJ'), ('travar', 'NN'), ('durante', 'NN'), ('uso', 'NN'), ('.', '.'), ('aparelho', 'JJ'), ('apreciado', 'JJ'), ('funções', 'NN'), ('adicionais', 'NN'), ('nfc', 'JJ'), ('smart', 'JJ'), ('view', 'NN'), (',', ','), ('excelente', 'JJ'), ('custo-benefício', 'NN'), ('.', '.')], [('gostei', 'NN'), ('bastante', 'NN'), (',', ','), ('tela', 'JJ'), ('ótimo', 'NN'), ('tamanho', 'NN'), ('...', ':'), ('achei', 'JJ'), ('bem', 'NN'), ('satisfatório', 'NN'), ('preço', 'NN'), ('celular', 'NN'), (',', ','), ('reclamar', 'NN'), ('enquanto', 'NN'), (',', ','), ('bem', 'NN'), ('satisfeito', 'NN'), ('!', '.')], [('celular', 'JJ'), ('bonito', 'NN'), (',', ','), ('veio', 'FW'), ('tudo', 'JJ'), ('certinho', 'NN'), ('!', '.'), ('!', '.'), ('gostei', 'NN'), ('pq', 'NN'), ('nã', 'JJ'), ('embalaram', 'NN'), ('cell', 'NN'), ('saco', 'NN'), ('bolha', 'NN'), (',', ','), ('caixa', 'NN'), ('veio', 'NN'), ('nenhuma', 'JJ'), ('proteção', 'NN'), ('!', '.'), ('telefone', 'NN'), ('nenhum', 'JJ'), ('arranhão', 'NN'), ('.', '.'), ('tirando', 'NN'), (',', ','), ('tudo', 'JJ'), ('certo', 'NN'), ('.', '.')], [('dei', 'NN'), ('presente', 'NN'), ('pra', 'NN'), ('esposa', 'NN'), ('...', ':'), ('enquanto', 'CC'), ('tudo', 'JJ'), ('certo', 'NN'), ('.', '.')], [('enquanto', 'IN'), ('achando', 'JJ'), ('bom', 'NN'), (',', ','), ('fotos', 'JJ'), ('boas', 'NN'), (',', ','), ('respostas', 'VB'), ('rápidas', 'JJ'), ('biometria', 'NNS'), (',', ','), ('além', 'JJ'), ('disso', 'VBP'), ('smart', 'JJ'), ('view', 'NN'), ('...', ':'), ('bom', 'NN'), ('.', '.'), ('obs', 'JJ'), ('carregador', 'NN'), ('fraco', 'NN'), ('demorar', 'NN'), ('carregar', 'NN'), ('telefone', 'NN'), ('pouco', 'NN'), ('.', '.')], [('produto', 'NN'), ('bom', 'NN'), ('bateria', 'NN'), ('dura', 'NN'), ('bastante', 'NN'), ('gostei', 'NN'), ('tamanho', 'NN'), (',', ','), ('acostumado', 'IN'), ('celular', 'JJ'), ('maior', 'NN'), (',', ','), ('pra', 'NN'), ('gosta', 'NN'), ('recomendo', 'NN'), ('podem', 'NN'), ('comprar', 'NN'), ('medo', 'NN'), ('.', '.')], [('produto', 'NN'), ('design', 'NN'), ('lindo', 'NN'), (',', ','), ('porém', 'NN'), ('pouca', 'NN'), ('durabilidade', 'NN'), ('relação', 'NN'), ('bateria', 'NN'), ('...', ':'), ('faço', 'JJ'), ('devolução', 'NN'), ('devido', 'NN'), ('necessidade', 'VBD'), ('relação', 'JJ'), ('aparelho', 'NN'), ('.', '.')], [('sorte', 'NN'), ('compra', 'NN'), (',', ','), ('celular', 'JJ'), ('mês', 'NN'), ('uso', 'JJ'), ('tá', 'NN'), ('travando', 'NN'), ('...', ':'), ('obedece', 'NN'), ('.', '.')], [('qualidade', 'NN'), ('câmeras', 'NNS'), ('deixa', 'VBP'), ('desejar', 'NN'), (',', ','), ('básico', 'NN'), (',', ','), ('dá', 'JJ'), ('pro', 'FW'), ('gasto', 'NN'), ('...', ':'), ('precisa', 'NN'), ('adquirir', 'JJ'), ('separadamente', 'NN'), ('.', '.')], [('celular', 'JJ'), ('mediano', 'NN'), (',', ','), ('esperava', 'NN'), ('samsung', 'NN'), ('...', ':'), ('travando', 'NN'), ('app', 'NN'), ('usado', 'JJ'), ('momento', 'NN'), ('fazendo', 'NN'), ('desigualdade', 'NN'), ('tela', 'NN'), ('reiniciar', 'NN'), ('app', 'NN'), ('.', '.')], [('produto', 'NN'), ('infelizmente', 'NN'), ('após', 'NN'), ('poucos', 'NN'), ('meses', 'VBZ'), ('uso', 'JJ'), (',', ','), ('apresenta', 'JJ'), ('defeitos', 'NN'), ('travamento', 'NN'), ('acessos', 'NN'), ('remotos', 'NN'), ('apps', 'NN'), ('ligações', 'NN'), ('.', '.')], [('produto', 'NN'), ('bom', 'NN'), ('bateria', 'NN'), ('dura', 'NN'), ('bastante', 'NN'), ('gostei', 'NN'), ('tamanho', 'NN'), ('...', ':'), ('pra', 'NN'), ('gosta', 'NN'), ('recomendo', 'NN'), ('podem', 'NN'), ('comprar', 'NN'), ('medo', 'NN'), ('.', '.')], [('produto', 'NN'), ('design', 'NN'), ('lindo', 'NN'), (',', ','), ('porém', 'NN'), ('pouca', 'NN'), ('durabilidade', 'NN'), ('relação', 'NN'), ('bateria', 'NN'), ('...', ':'), ('faço', 'JJ'), ('devolução', 'NN'), ('devido', 'NN'), ('necessidade', 'VBD'), ('relação', 'JJ'), (' ...
#
#
# Chunks:
# [Tree('S', [('amplamente', 'NN'), ('elogiado', 'NN'), ('rapidez', 'NN'), (',', ','), ('ótima', 'NNP'), ('câmera', 'NN'), ('bateria', 'NN'), ('durável', 'NN'), (',', ','), ('além', 'JJ'), ('travar', 'NN'), ('durante', 'NN'), ('uso', 'NN'), ('.', '.'), ('aparelho', 'JJ'), ('apreciado', 'JJ'), ('funções', 'NN'), ('adicionais', 'NN'), ('nfc', 'JJ'), ('smart', 'JJ'), ('view', 'NN'), (',', ','), ('excelente', 'JJ'), ('custo-benefício', 'NN'), ('.', '.')]), Tree('S', [('gostei', 'NN'), ('bastante', 'NN'), (',', ','), ('tela', 'JJ'), ('ótimo', 'NN'), ('tamanho', 'NN'), ('...', ':'), ('achei', 'JJ'), ('bem', 'NN'), ('satisfatório', 'NN'), ('preço', 'NN'), ('celular', 'NN'), (',', ','), ('reclamar', 'NN'), ('enquanto', 'NN'), (',', ','), ('bem', 'NN'), ('satisfeito', 'NN'), ('!', '.')]), Tree('S', [('celular', 'JJ'), ('bonito', 'NN'), (',', ','), ('veio', 'FW'), ('tudo', 'JJ'), ('certinho', 'NN'), ('!', '.'), ('!', '.'), ('gostei', 'NN'), ('pq', 'NN'), ('nã', 'JJ'), ('embalaram', 'NN'), ('cell', 'NN'), ('saco', 'NN'), ('bolha', 'NN'), (',', ','), ('caixa', 'NN'), ('veio', 'NN'), ('nenhuma', 'JJ'), ('proteção', 'NN'), ('!', '.'), ('telefone', 'NN'), ('nenhum', 'JJ'), ('arranhão', 'NN'), ('.', '.'), ('tirando', 'NN'), (',', ','), ('tudo', 'JJ'), ('certo', 'NN'), ('.', '.')]), Tree('S', [('dei', 'NN'), ('presente', 'NN'), ('pra', 'NN'), ('esposa', 'NN'), ('...', ':'), ('enquanto', 'CC'), ('tudo', 'JJ'), ('certo', 'NN'), ('.', '.')]), Tree('S', [('enquanto', 'IN'), ('achando', 'JJ'), ('bom', 'NN'), (',', ','), ('fotos', 'JJ'), ('boas', 'NN'), (',', ','), ('respostas', 'VB'), ('rápidas', 'JJ'), ('biometria', 'NNS'), (',', ','), ('além', 'JJ'), ('disso', 'VBP'), ('smart', 'JJ'), ('view', 'NN'), ('...', ':'), ('bom', 'NN'), ('.', '.'), ('obs', 'JJ'), ('carregador', 'NN'), ('fraco', 'NN'), ('demorar', 'NN'), ('carregar', 'NN'), ('telefone', 'NN'), ('pouco', 'NN'), ('.', '.')]), Tree('S', [('produto', 'NN'), ('bom', 'NN'), ('bateria', 'NN'), ('dura', 'NN'), ('bastante', 'NN'), ('gostei', 'NN'), ('tamanho', 'NN'), (',', ','), ('acostumado', 'IN'), ('celular', 'JJ'), ('maior', 'NN'), (',', ','), ('pra', 'NN'), ('gosta', 'NN'), ('recomendo', 'NN'), ('podem', 'NN'), ('comprar', 'NN'), ('medo', 'NN'), ('.', '.')]), Tree('S', [('produto', 'NN'), ('design', 'NN'), ('lindo', 'NN'), (',', ','), ('porém', 'NN'), ('pouca', 'NN'), ('durabilidade', 'NN'), ('relação', 'NN'), ('bateria', 'NN'), ('...', ':'), ('faço', 'JJ'), ('devolução', 'NN'), ('devido', 'NN'), ('necessidade', 'VBD'), ('relação', 'JJ'), ('aparelho', 'NN'), ('.', '.')]), Tree('S', [('sorte', 'NN'), ('compra', 'NN'), (',', ','), ('celular', 'JJ'), ('mês', 'NN'), ('uso', 'JJ'), ('tá', 'NN'), ('travando', 'NN'), ('...', ':'), ('obedece', 'NN'), ('.', '.')]), Tree('S', [('qualidade', 'NN'), ('câmeras', 'NNS'), ('deixa', 'VBP'), ('desejar', 'NN'), (',', ','), ('básico', 'NN'), (',', ','), ('dá', 'JJ'), ('pro', 'FW'), ('gasto', 'NN'), ('...', ':'), ('precisa', 'NN'), ('adquirir', 'JJ'), ('separadamente', 'NN'), ('.', '.')]), Tree('S', [('celular', 'JJ'), ('mediano', 'NN'), (',', ','), ('esperava', 'NN'), ('samsung', 'NN'), ('...', ':'), ('travando', 'NN'), ('app', 'NN'), ('usado', 'JJ'), ('momento', 'NN'), ('fazendo', 'NN'), ('desigualdade', 'NN'), ('tela', 'NN'), ('reiniciar', 'NN'), ('app', 'NN'), ('.', '.')]), Tree('S', [('produto', 'NN'), ('infelizmente', 'NN'), ('após', 'NN'), ('poucos', 'NN'), ('meses', 'VBZ'), ('uso', 'JJ'), (',', ','), ('apresenta', 'JJ'), ('defeitos', 'NN'), ('travamento', 'NN'), ('acessos', 'NN'), ('remotos', 'NN'), ('apps', 'NN'), ('ligações', 'NN'), ('.', '.')]), Tree('S', [('produto', 'NN'), ('bom', 'NN'), ('bateria', 'NN'), ('dura', 'NN'), ('bastante', 'NN'), ('gostei', 'NN'), ('tamanho', 'NN'), ('...', ':'), ('pra', 'NN'), ('gosta', 'NN'), ('recomendo', 'NN'), ('podem', 'NN'), ('comprar', 'NN'), ('medo', 'NN'), ('.', '.')]), Tree('S', [('produto', 'NN'), ('design', 'NN'), ('lindo', 'NN'), (',', ','), ('porém', 'NN'), ('pouca', 'NN'), ('durabilidade', 'NN'), ('relação' ...
